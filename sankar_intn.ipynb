# %% [markdown]
# <a href="https://colab.research.google.com/github/sanshub99/Intenship/blob/main/sankar_intn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Electric Vehicle Population Insights and Analysis

# %% [markdown]
# ## Problem Statement Overview:
#
# Electric Vehicle Population Insights and Analysis is the process of examining a dataset to understand its key characteristics, patterns, and detect any anomalies. This initial step in data analysis often uses a variety of graphs and plots to visualize data, along with statistical methods to draw inferences.
#
# The aim of Electric Vehicle Population Insights and Analysis is not to reach a specific conclusion or confirm a pre-existing hypothesis; rather, it is an exploratory phase intended to uncover insights and generate ideas on how the data could be further leveraged for predicting outcomes or developing machine learning models.

# %% [markdown]
# ## Introduction to Electric Vehicles
#
# An electric vehicle (EV) is powered by one or more electric motors and can operate using electricity from external sources or autonomously from a battery. In some cases, batteries are recharged by solar panels or through systems that convert fuel to electricity, such as fuel cells or generators.
#
# EVs cover a broad range of vehicles, including road and rail transport, marine vessels, aircraft, and even spacecraft. In road transportation, EVs align with other innovative technologies—autonomous driving, connected systems, and shared mobility—forming what is known as Connected, Autonomous, Shared, and Electric (CASE) Mobility, a vision for the future of mobility.
#
# Electric vehicles first emerged in the late 19th century, at a time when electricity offered a smooth, easy driving experience compared to early gasoline-powered vehicles. While internal combustion engines became the dominant propulsion method for cars and trucks over the next century, electric power has remained prevalent in other types of vehicles, such as trains and smaller personal and utility vehicles.

# %% [markdown]
# ## Data Description:

# %% [markdown]
# The dataset provides detailed information about electric vehicles (EVs) and their associated attributes. It contains both numerical and categorical features that describe vehicle specifications, geographical details, and administrative classifications. Below is a breakdown of the dataset:

# %% [markdown]
# ## **1. Vehicle Identification and Specifications**
#
# * **VIN (1-10):** A partial Vehicle Identification Number representing the unique identity of the vehicle.
# * **Model Year:** The year in which the vehicle was manufactured.
# * **Make:** The manufacturer or brand of the vehicle.
# * **Model:** The specific model of the vehicle.
# * **Electric Vehicle Type:** Indicates the type of EV, such as Battery Electric
#   Vehicle (BEV) or Plug-in Hybrid Electric Vehicle (PHEV).
# * **Electric Range:** The maximum distance the vehicle can travel on electric power alone (in miles).
# * **Base MSRP:** The Manufacturer’s Suggested Retail Price (MSRP) for the vehicle's base model.
# ## **2. Geographic and Administrative Information**
# * **County:** The county where the vehicle is registered.
# * **City:** The city where the vehicle is registered.
# * **State:** The state where the vehicle is registered.
# * **Postal Code:** The postal or ZIP code associated with the vehicle's registration.
# * **Legislative District:** The legislative district corresponding to the vehicle’s registration location.
# *  **2020 Census Tract:** The census tract as per the 2020 U.S. Census, providing geographical granularity.
# * **Vehicle Location:** The geographical coordinates or general area where the vehicle is located.
# ## **3. Environmental and Utility Details**
# * **Clean Alternative Fuel Vehicle (CAFV) Eligibility:** Indicates whether the vehicle qualifies for clean alternative fuel incentives.
# * **Electric Utility:** The electric utility company servicing the vehicle’s registered location.
# ## **4. Administrative Identifiers**
# * **DOL Vehicle ID:** The unique identifier assigned by the Department of Licensing for the vehicle.
#
# ## **Potential Uses of the Data**
#
# This dataset can be used for:
# * Analyzing the adoption and distribution of electric vehicles across different regions.
# * Evaluating the impact of EVs on infrastructure, such as electric utility demand.
# * Identifying trends in EV pricing and range based on make, model, and year.
# * Understanding the relationship between geographical attributes and EV adoption rates.

# %% [markdown]
# ## Data collection

# %%
#Ignor warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Electric_Vehicle_Population_Data.csv')  # For CSV files

# %%
df
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %%
df["Electric Range"].describe()
# Out:
# count    191407.000000
# mean         55.657442
# std          90.151930
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          72.000000
# max         337.000000
# Name: Electric Range, dtype: float64

# %%
df["Electric Range"].value_counts()
# Out:
# Electric Range
# 0      102133
# 215      6415
# 32       4476
# 25       4290
# 220      4047
#         ...
# 11          3
# 95          3
# 51          2
# 46          2
# 57          2
# Name: count, Length: 103, dtype: int64

# %%
# Define the bins and custom labels
bins = [0, 50, 100, 252, 500]
labels = ['Low Range', 'Medium Range', 'High Range', 'Very High Range']

# Create the new column with specific labels
df['Electric Range'] = pd.cut(df['Electric Range'], bins=bins, labels=labels, include_lowest=True)

(df)
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %%
df["Electric Range"].value_counts() #TARGET
# Out:
# Electric Range
# Low Range          140045
# High Range          28377
# Medium Range        13265
# Very High Range      9720
# Name: count, dtype: int64

# %%
TARGET=df["Electric Range"] #CLASSIFICATION

# %%
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility   Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible  Very High Range
# ...

# %%
### Identify numerical and categorical columns

# %%
#Numerical columns
num_cols = df.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['Postal Code', 'Model Year', 'Base MSRP', 'Legislative District',
#        'DOL Vehicle ID', '2020 Census Tract'],
#       dtype='object')

# %%
#categorical columns
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Make', 'Model',
#        'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Vehicle Location',
#        'Electric Utility'],
#       dtype='object')

# %% [markdown]
# After the finding out of 17 columns, 7 are numerical and 10 are categorical

# %% [markdown]
# ### Checking null values

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.002090
# City                                                 0.002090
# State                                                0.000000
# Postal Code                                          0.002090
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.216293
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.004180
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Checking for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values

# %% [markdown]
# ### Understand the distribution of data

# %%
#Discriptive statistics
df.describe().T
# Out:
#                          count          mean           std           min  \
# Postal Code           191403.0  9.817782e+04  2.392809e+03  1.731000e+03
# Model Year            191407.0  2.020732e+03  2.990487e+00  1.997000e+03
# Base MSRP             191407.0  9.947733e+02  8.050523e+03  0.000000e+00
# Legislative District  190993.0  2.901688e+01  1.490942e+01  1.000000e+00
# DOL Vehicle ID        191407.0  2.237202e+08  7.398058e+07  4.385000e+03
# 2020 Census Tract     191403.0  5.297759e+10  1.573588e+09  1.001020e+09
#
#                                25%           50%           75%           max
# Postal Code           9.805200e+04  9.812500e+04  9.837100e+04  9.957700e+04
# Model Year            2.019000e+03  2.022000e+03  2.023000e+03  2.025000e+03
# Base MSRP             0.000000e+00  0.000000e+00  0.000000e+00  8.450000e+05
# Legislative District  1.700000e+01  3.300000e+01  4.200000e+01  4.900000e+01
# ...

# %%
df.describe(include='object').T
# Out:
#                                                     count unique  \
# VIN (1-10)                                         191407  11487
# County                                             191403    197
# City                                               191403    744
# State                                              191407     46
# Make                                               191407     42
# Model                                              191407    147
# Electric Vehicle Type                              191407      2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  191407      3
# Vehicle Location                                   191399    891
# Electric Utility                                   191403     75
#
#                                                                                                  top  \
# VIN (1-10)                                                                                7SAYGDEE6P
# ...

# %% [markdown]
# ### Analysing numerical columns

# %%
plt.figure(figsize=(15, 10))
#enumerate() is a built-in Python function that allows you to loop over an iterable (like a list) and have an automatic counter.
for i, col in enumerate(num_cols):
    plt.subplot(5, 4, i+1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# This insight we can see there some outliers in 6 columns Postal Code, Model Year, Base MSRP, DOL Vechile ID and 2020 Census Tract.

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols):
    plt.subplot(5, 4, i+1)
    sns.scatterplot(data=df,x=col,y='Electric Range')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# There is the relation with target varible and others

# %% [markdown]
# ### Correlation

# %%
# correlation with heatmap to interpret the relation and multicolliniarity
plt.figure(figsize=(15,15))
sns.heatmap(df[num_cols].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is no multicolliniarity

# %% [markdown]
# ### Analysing categorical columns

# %%
# Checking the number of unique values in each categorical column
unique_counts = df[cat_cols].nunique()
unique_counts
# Out:
# VIN (1-10)                                           11487
# County                                                 197
# City                                                   744
# State                                                   46
# Make                                                    42
# Model                                                  147
# Electric Vehicle Type                                    2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        3
# Vehicle Location                                       891
# Electric Utility                                        75
# dtype: int64

# %% [markdown]
# **Summary of Unique Values:**
#
# ****
# In our data set it has two type of columns. column with low cardinality and high cardinality.
#
# - **Low Cardinality Columns:**
#   - Electric Vehicle Type (2 unique values)
#   - Clean Alternative Fuel Vehicle (CAFV) Eligibility (3 unique values)
# ****
# One hot encoding method is suitable for these low cardinality columns.
# ****
# - **High Cardinality Columns:**
#   - VIN (1-10) (11487 unique values)
#   - County (197 unique values)
#   - com_county (62 unique values)
#   - data_field (15 unique values)
# ****

# %% [markdown]
# **Here VIN (1-10), Vehicle Location & Electric Utility columns are not necessary.**

# %% [markdown]
# ##Data Visulaization

# %%
import plotly.express as px

# %%
#Lets check from which county we have more entries from (Top 10)

Counties = df.groupby('County').count().sort_values(by='City',ascending=False)['City'].index
values = df.groupby('County').count().sort_values(by='City',ascending=False)['City'].values

px.bar(x=list(Counties)[:10],y=values[:10],labels={'x':"County Name",'y':"Number of Cars"},color=values[:10])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#lets see which company makes most of the electric vehicles
Companies = df.groupby('Make').count().sort_values(by='City',ascending=False)['City'].index
values = df.groupby('Make').count().sort_values(by='City',ascending=False)['City'].values


plt.figure(figsize=(9,5))
sns.barplot(x=list(Companies)[:10],y=values[:10],edgecolor='.2',palette='Set2')
plt.xticks(rotation='vertical')
plt.xlabel('Companies')
plt.ylabel('Count')
plt.show()

# %%
#Top 10 models in use

Models = df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].index
values = df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].values


plt.figure(figsize=(9,5))
sns.barplot(x=list(Models)[:10],y=values[:10],edgecolor='.2',palette='Set2')
plt.xticks(rotation='vertical')
plt.xlabel('Models')
plt.ylabel('Count')
plt.show()

# %%
#Percentage of BEV vs PHEV

Vehicle_type = list(df.groupby('Electric Vehicle Type').count()['County'].index)
values = df.groupby('Electric Vehicle Type').count()['County'].values

px.pie(names=Vehicle_type,values=values,height=400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#lets see top20 most sold cars and top20 most range giving vehicles and check if there is any correlation

top_10_vehicles = list(df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].index)[:10]

top_10_range =  df.sort_values(by='Electric Range',ascending=False)['Model'].unique()[:10]

top_10_vehicles
# Out:
# ['MODEL Y',
#  'MODEL 3',
#  'LEAF',
#  'MODEL S',
#  'BOLT EV',
#  'MODEL X',
#  'VOLT',
#  'ID.4',
#  'MUSTANG MACH-E',
#  'WRANGLER']

# %%
top_10_range
# Out:
# array(['MODEL S', 'BOLT EV', 'MODEL 3', 'MODEL Y', 'MODEL X', 'KONA',
#        'LEAF', 'PS2', 'E-TRON', 'E-GOLF'], dtype=object)

# %%
#column with unique values and its count
for col in cat_cols:
    print(f"\033[1mValues in {col}:\033[0m\n{df[col].unique()}")
    print(f"\033[1mNumber of unique values in {col}:\033[0m {df[col].nunique()}\n")
    print("\n" + "-"*80 + "\n")
# Out:
# Values in VIN (1-10):
# ['5YJSA1E22K' '3MW39FS05R' '1N4AZ0CP0F' ... 'KL8CK6S09E' 'WA1VCBGE5P'
#  '3MW5P7J05M']
# Number of unique values in VIN (1-10): 11487
#
#
# --------------------------------------------------------------------------------
#
# Values in County:
# ['King' 'Yakima' 'Snohomish' 'Thurston' 'Kitsap' 'Whitman' 'Walla Walla'
#  'Kittitas' 'Douglas' 'Grant' 'Chelan' 'Skagit' 'Stevens' nan 'Maricopa'
#  'Clark' 'Cowlitz' 'Jefferson' 'Island' 'Clallam' 'Klickitat' 'Spokane'
#  'Pierce' 'Mason' 'San Juan' 'Benton' 'Whatcom' 'Okanogan' 'Lewis'
#  'Grays Harbor' 'Asotin' 'Pacific' 'Wake' 'Franklin' 'Skamania' 'Columbia'
#  'Wichita' 'Lincoln' 'El Paso' 'Garfield' 'Adams' 'Hillsborough' 'Sonoma'
#  'Wahkiakum' 'Pend Oreille' 'Marin' 'Monterey' 'Cumberland' 'Lee' 'Ferry'
#  'San Diego' 'Nueces' 'Stafford' 'Washoe' 'Kern' 'DeKalb' 'Richland'
#  'Pulaski' 'Platte' 'Bexar' 'Goochland' 'Kings' 'Santa Clara' 'Madison'
# ...

# %% [markdown]
# #

# %%
# Distribution of column and unique values
for col in cat_cols:
    print(f"\033[1mDistribution of {col}:\033[0m")
    print(df[col].value_counts())

    # Bar plot visualization
    plt.figure(figsize=(15, 10))
    sns.countplot(x=col, data=df)
    plt.title(f'Bar Plot of {col}')
    plt.xticks(rotation=90)

    # Grid lines only for y-axis
    plt.grid(axis='y')

    plt.show()
    print("\n" + "-"*125 + "\n")
# Out:
# Distribution of VIN (1-10):
# VIN (1-10)
# 7SAYGDEE6P    1236
# 7SAYGDEE7P    1220
# 7SAYGDEE8P    1187
# 7SAYGDEE5P    1184
# 7SAYGDEEXP    1175
#               ...
# KMHC75LD6K       1
# 1G1RB6S5XK       1
# YV4BR00Z5N       1
# JN1DF0BB4R       1
# 3MW5P7J05M       1
# Name: count, Length: 11487, dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
#
# Distribution of County:
# County
# King          99076
# Snohomish     22643
# Pierce        14932
# Clark         11335
# Thurston       6969
#               ...
# New York          1
# Miami-Dade        1
# Mobile            1
# Beaufort          1
# Pitt              1
# Name: count, Length: 197, dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
#
# Distribution of City:
# City
# Seattle                    31436
# Bellevue                    9582
# ...

# %%
#cross tabulation between target variable and others
for col in cat_cols:
    print(f"\033[1mCrosstab of 'Electric Range' and '{col}':\033[0m")
    print(pd.crosstab(df['Electric Range'], df[col], margins =True))
    print("\n" + "-"*80 + "\n")
# Out:
# Crosstab of 'Electric Range' and 'VIN (1-10)':
# VIN (1-10)       1C4JJXN60P  1C4JJXN61P  1C4JJXN62P  1C4JJXN63P  1C4JJXN64P  \
# Electric Range
# Low Range                37          34          31          38          30
# Medium Range              0           0           0           0           0
# High Range                0           0           0           0           0
# Very High Range           0           0           0           0           0
# All                      37          34          31          38          30
#
# VIN (1-10)       1C4JJXN65P  1C4JJXN66P  1C4JJXN67P  1C4JJXN68P  1C4JJXN69P  \
# Electric Range
# Low Range                35          33          35          30          33
# Medium Range              0           0           0           0           0
# High Range                0           0           0           0           0
# Very High Range           0           0           0           0           0
# ...

# %% [markdown]
# \- Above insight helps you understand the distribution of all categorical columns.

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# ## Data Preprocessing

# %%
df1=df.copy()
print('original data :', df.shape)
print('copied data :', df1.shape)
# Out:
# original data : (191407, 17)
# copied data : (191407, 17)

# %%
df1
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %% [markdown]
# ### Remove unwanted columns

# %%
df1.drop(['VIN (1-10)','County','Postal Code','Base MSRP', 'Vehicle Location','Electric Utility','2020 Census Tract'], axis=1, inplace=True)
df1.shape
# Out:
# (191407, 10)

# %% [markdown]
# #

# %% [markdown]
# ### Handling missing values

# %%
df1.isnull().sum()
# Out:
# City                                                   4
# State                                                  0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# dtype: int64

# %% [markdown]
# * For the missing value treatment we can use mean, median, mode or KNNimputer.
# * KNN Imputer is a method used for imputing missing values by using the k-nearest neighbors approach.

# %%
# filling null values with 'unknown'
df1['City'].fillna(0, inplace=True)

# filling null values with '0'
df1['Legislative District'].fillna(0, inplace=True)

# %%
df1.isnull().sum()
# Out:
# City                                                 0
# State                                                0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# dtype: int64

# %%
### Handling Outliers

# %%
plt.figure(figsize=(15, 10))
numeric_columns = df1.select_dtypes(include='number').columns
for i, col in enumerate(numeric_columns):
    plt.subplot(5, 4, i+1)
    sns.boxplot(y=df1[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here IQR method is used for outlier treatment

# %%
def whisker(df1, column):
    q1 = df1[column].quantile(0.25)
    q3 = df1[column].quantile(0.75)
    iqr = q3 - q1
    lw = q1 - 1.5 * iqr
    uw = q3 + 1.5 * iqr

    # Replace outliers with upper and lower bounds
    df1[column] = df1[column].apply(lambda x: uw if x > uw else (lw if x < lw else x))

whisker(df1, 'Model Year')
whisker(df1, 'DOL Vehicle ID')

# %%
plt.figure(figsize=(15, 10))
numeric_columns = df1.select_dtypes(include='number').columns
for i, col in enumerate(numeric_columns):
    plt.subplot(5, 4, i+1)
    sns.boxplot(y=df1[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# All the outliers are removed

# %% [markdown]
# ### skewness and kurtosis

# %%
import pandas as pd
from scipy.stats import skew, kurtosis

# Ensure numeric columns are defined
numeric_columns = df1.select_dtypes(include="number").columns

# Calculate skewness and kurtosis
skewness = df1[numeric_columns].apply(skew)
kurt = df1[numeric_columns].apply(lambda x: kurtosis(x, fisher=False))


def kew_kurt(stat_name, data, threshold, direction):
    if not data.empty:
        print(f'\nVariables with {direction} {stat_name} ({stat_name} < {threshold}):\n', data)
    else:
        print(f'\nNo variables with {direction} {stat_name} ({stat_name} > {threshold})')


# Print skewness and kurtosis results

print("\033[1;4m" + "skewness" + "\033[0m" + '\n' + str(skewness))

kew_kurt("Skewness", skewness[skewness > 1], 1, "positive")
kew_kurt("Skewness", skewness[skewness < -1], -1, "negative")


print("\n" + "-" * 80 + "\n")


print("\033[1;4m" + "kurtosis" + "\033[0m" + '\n' + str(kurt))

kew_kurt("Kurtosis", kurt[kurt < 3], 3, "platykurtic") #it means the data has lighter tails
kew_kurt("Kurtosis", kurt[kurt > 3], 3, "leptokurtic") #it means the data has heavy tails
# Out:
# skewness
# Model Year             -1.081386
# Legislative District   -0.442582
# DOL Vehicle ID         -0.163656
# dtype: float64
#
# No variables with positive Skewness (Skewness > 1)
#
# Variables with negative Skewness (Skewness < -1):
#  Model Year   -1.081386
# dtype: float64
#
# --------------------------------------------------------------------------------
#
# kurtosis
# Model Year              3.230472
# Legislative District    1.879111
# DOL Vehicle ID          3.437256
# dtype: float64
#
# Variables with platykurtic Kurtosis (Kurtosis < 3):
#  Legislative District    1.879111
# dtype: float64
#
# Variables with leptokurtic Kurtosis (Kurtosis < 3):
#  Model Year        3.230472
# DOL Vehicle ID    3.437256
# dtype: float64

# %%
# Assuming 'df' is your DataFrame
numeric_df1 = df1.select_dtypes(include=[np.number])

# Calculate skewness and kurtosis
skewness = numeric_df1.apply(lambda x: skew(x.dropna()))
kurt = numeric_df1.apply(lambda x: kurtosis(x.dropna()))

# Print skewness and kurtosis
print("Skewness:\n", skewness)
print("Kurtosis:\n", kurt)
# Out:
# Skewness:
#  Model Year             -1.081386
# Legislative District   -0.442582
# DOL Vehicle ID         -0.163656
# dtype: float64
# Kurtosis:
#  Model Year              0.230472
# Legislative District   -1.120889
# DOL Vehicle ID          0.437256
# dtype: float64

# %% [markdown]
# Here we can see the differends after treating outleirs and missing values etc..

# %%
numerical_columns= df1.select_dtypes(include=['number']).columns.tolist()

for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df1[col], kde=True, bins=15)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
sns.pairplot(df1)

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_columns):
    plt.subplot(5, 3, i+1)
    sns.scatterplot(data=df1,x=col,y='Electric Range')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df1[numeric_columns].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Encoding Categorical Variables

# %%
X = df1.drop(columns=['Electric Range'])
y = df1['Electric Range']

# %%
print(X.shape)
print(y.shape)
# Out:
# (191407, 9)
# (191407,)

# %%
# Checking the number of unique values in each categorical column
unique_counts = df1.select_dtypes(include='object').nunique()
unique_counts
# Out:
# City                                                 745
# State                                                 46
# Make                                                  42
# Model                                                147
# Electric Vehicle Type                                  2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      3
# dtype: int64

# %% [markdown]
# - **Low Cardinality Columns:**
#   - Electric Vehicle Type (2 unique values)
#   - Clean Alternative Fuel Vehicle (CAFV) Eligibility (3 unique values)
#
# - **High Cardinality Columns:**
#   - City (745 unique values)
#   - Model (147 unique values)
#   - State (46 unique values)
#   - Make (42 unique values)

# %%
# One-Hot Encoding for low cardinality columns
cat_encoded = pd.get_dummies(X, columns=['Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility'], drop_first=True)


# Frequency Encoding for high cardinality columns
for col in ['City', 'State', 'Make', 'Model']:
    freq_encoding = X[col].value_counts(normalize=True)  # Calculate the frequency of each category
    cat_encoded[col] = X[col].map(freq_encoding)  # Map the original values to their frequency


cat_encoded.head(), y.head()
# Out:
# (       City     State  Model Year      Make     Model  Legislative District  \
#  0  0.164236  0.997837      2019.0  0.442356  0.041111                  43.0
#  1  0.000209  0.997837      2024.0  0.041759  0.002476                  15.0
#  2  0.015935  0.997837      2015.0  0.074391  0.070212                  11.0
#  3  0.032799  0.997837      2015.0  0.442356  0.041111                   1.0
#  4  0.003944  0.997837      2022.0  0.037517  0.013563                  14.0
#
#     DOL Vehicle ID  \
#  0     202233958.0
#  1     264425178.0
#  2     114962025.0
#  3     232724670.0
#  4     221023589.0
#
#     Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)  \
#  0                                              False
#  1                                               True
#  2                                              False
#  3                                              False
#  4                                               True
#
# ...

# %%
cat_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 10 columns):
#  #   Column                                                                                                          Non-Null Count   Dtype
# ---  ------                                                                                                          --------------   -----
#  0   City                                                                                                            191407 non-null  float64
#  1   State                                                                                                           191407 non-null  float64
#  2   Model Year                                                                                                      191407 non-null  float64
#  3   Make                                                                                                            191407 non-null  float64
# ...

# %%
X = cat_encoded
X.head()
# Out:
#        City     State  Model Year      Make     Model  Legislative District  \
# 0  0.164236  0.997837      2019.0  0.442356  0.041111                  43.0
# 1  0.000209  0.997837      2024.0  0.041759  0.002476                  15.0
# 2  0.015935  0.997837      2015.0  0.074391  0.070212                  11.0
# 3  0.032799  0.997837      2015.0  0.442356  0.041111                   1.0
# 4  0.003944  0.997837      2022.0  0.037517  0.013563                  14.0
#
#    DOL Vehicle ID  \
# 0     202233958.0
# 1     264425178.0
# 2     114962025.0
# 3     232724670.0
# 4     221023589.0
#
#    Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
#
# ...

# %%
X.shape
# Out:
# (191407, 10)

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 191407 entries, 0 to 191406
# Series name: Electric Range
# Non-Null Count   Dtype
# --------------   -----
# 191407 non-null  category
# dtypes: category(1)
# memory usage: 187.2 KB

# %%
y.value_counts()
# Out:
# Electric Range
# Low Range          140045
# High Range          28377
# Medium Range        13265
# Very High Range      9720
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# Encoding target variable
ylabel_encoder = LabelEncoder()
y = ylabel_encoder.fit_transform(y)

# Create a mapping of original labels to numeric values
label_mapping = dict(zip(ylabel_encoder.classes_, ylabel_encoder.transform(ylabel_encoder.classes_)))
#zip: Combines the original class labels and their encoded values into pairs.
#dict: Converts the pairs into a dictionary format for easy readability.

print("Label Mapping:", label_mapping)
print("Encoded Labels:", y)
# Out:
# Label Mapping: {'High Range': 0, 'Low Range': 1, 'Medium Range': 2, 'Very High Range': 3}
# Encoded Labels: [3 1 2 ... 1 1 1]

# %%
y
# Out:
# array([3, 1, 2, ..., 1, 1, 1])

# %% [markdown]
# ## Feature Scaling

# %%
# Identify binary columns (excluding the target variable)

binary_cols = X.columns[(X.nunique() == 2)].tolist()
continuous_cols = [col for col in X.columns if col not in binary_cols]

# %%
X.columns
# Out:
# Index(['City', 'State', 'Model Year', 'Make', 'Model', 'Legislative District',
#        'DOL Vehicle ID',
#        'Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility_Eligibility unknown as battery range has not been researched',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility_Not eligible due to low battery range'],
#       dtype='object')

# %%
binary_cols
# Out:
# ['Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)',
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility_Eligibility unknown as battery range has not been researched',
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility_Not eligible due to low battery range']

# %%
continuous_cols
# Out:
# ['City',
#  'State',
#  'Model Year',
#  'Make',
#  'Model',
#  'Legislative District',
#  'DOL Vehicle ID']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X[continuous_cols] = scaler.fit_transform(X[continuous_cols])

# %%
X.T
# Out:
#                                                       0         1       \
# City                                                 2.19452 -0.719861
# State                                               0.046558  0.046558
# Model Year                                         -0.596233  1.106848
# Make                                                1.118403 -0.888622
# Model                                              -0.503588 -0.972602
# Legislative District                                0.939264 -0.933128
# DOL Vehicle ID                                      -0.33194  0.714625
# Electric Vehicle Type_Plug-in Hybrid Electric V...     False      True
# Clean Alternative Fuel Vehicle (CAFV) Eligibili...     False     False
# Clean Alternative Fuel Vehicle (CAFV) Eligibili...     False      True
#
#                                                       2         3       \
# City                                               -0.440453 -0.140809
# ...

# %% [markdown]
# ### Addressing the Class imbalance

# %%
y_series = pd.Series(y)
print(y_series.value_counts())
# Out:
# 1    140045
# 0     28377
# 2     13265
# 3      9720
# Name: count, dtype: int64

# %%
target_counts = y_series.value_counts()
imbalance_ratio = target_counts.max() / target_counts.min()
print(f"Imbalance Ratio: {imbalance_ratio}")
# Out:
# Imbalance Ratio: 14.40792181069959

# %% [markdown]
# ### Smote techniq

# %%
pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
print(df1.columns)
# Out:
# Index(['City', 'State', 'Model Year', 'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Legislative District', 'DOL Vehicle ID'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
smote = SMOTE(random_state=42)
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# %%
from collections import Counter

print("Before SMOTE:", Counter(y_train))
print("After SMOTE:", Counter(y_train_sm))
# Out:
# Before SMOTE: Counter({1: 98031, 0: 19864, 2: 9285, 3: 6804})
# After SMOTE: Counter({1: 98031, 2: 98031, 0: 98031, 3: 98031})

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Train the model
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_sm, y_train_sm)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      8513
#            1       1.00      1.00      1.00     42014
#            2       1.00      1.00      1.00      3980
#            3       0.99      0.99      0.99      2916
#
#     accuracy                           1.00     57423
#    macro avg       1.00      1.00      1.00     57423
# weighted avg       1.00      1.00      1.00     57423

# %%
# Example: Checking the mean of a feature for each class
feature_mean = X.groupby(y).mean()
print(feature_mean)
# Out:
#        City     State  Model Year      Make     Model  Legislative District  \
# 0  0.035444 -0.008059   -0.988331  0.394161  0.004096              0.071907
# 1 -0.014449  0.000755    0.401710 -0.059768  0.011252             -0.019643
# 2  0.051352  0.022217   -1.897019 -0.791365 -0.501186              0.034838
# 3  0.034626 -0.017670   -0.313542  0.790384  0.509893              0.025537
#
#    DOL Vehicle ID  \
# 0        0.133545
# 1        0.094072
# 2       -0.376816
# 3       -1.231012
#
#    Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)  \
# 0                                           0.006660
# 1                                           0.270649
# 2                                           0.273502
# 3                                           0.000000
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility_Eligibility unknown as battery range has not been researched  \
# 0                                           0.000000
# ...

# %% [markdown]
# ## Feature selection

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Feature Selection using Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
rf_feature_importances = pd.Series(rf_model.feature_importances_, index=X_train.columns)
rf_top_features = rf_feature_importances.nlargest(10)

# Feature Selection using SelectKBest with ANOVA F-test
k_best = SelectKBest(score_func=f_classif, k=10)
k_best.fit(X_train, y_train)
k_best_top_features = pd.Series(k_best.scores_, index=X_train.columns).nlargest(10)

# Display top 10 features from both methods
print("Random Forest Top Features:\n", rf_top_features)
print("\nSelectKBest Top Features:\n", k_best_top_features)
# Out:
# Random Forest Top Features:
#  Model Year                                                                                                        0.447667
# Clean Alternative Fuel Vehicle (CAFV) Eligibility_Eligibility unknown as battery range has not been researched    0.147804
# Make                                                                                                              0.107117
# Model                                                                                                             0.104744
# Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)                                                      0.097100
# DOL Vehicle ID                                                                                                    0.054001
# Clean Alternative Fuel Vehicle (CAFV) Eligibility_Not eligible due to low battery range                           0.037439
# ...

# %%
# Comparing Model Performance with the Top Features
# Model with Random Forest Top Features
rf_top_feature_columns = rf_top_features.index
X_train_rf = X_train[rf_top_feature_columns]
X_test_rf = X_test[rf_top_feature_columns]

rf_model.fit(X_train_rf, y_train)
y_pred_rf = rf_model.predict(X_test_rf)
rf_accuracy = accuracy_score(y_test, y_pred_rf)

# Model with SelectKBest Top Features
k_best_top_feature_columns = k_best_top_features.index
X_train_kbest = X_train[k_best_top_feature_columns]
X_test_kbest = X_test[k_best_top_feature_columns]

rf_model.fit(X_train_kbest, y_train)
y_pred_kbest = rf_model.predict(X_test_kbest)
kbest_accuracy = accuracy_score(y_test, y_pred_kbest)

# Displaying the results
print(f"\nRandom Forest Model Accuracy with Top Features: {rf_accuracy}")
print(f"SelectKBest Model Accuracy with Top Features: {kbest_accuracy}")
# Out:
# Random Forest Model Accuracy with Top Features: 0.9990770248854989
# SelectKBest Model Accuracy with Top Features: 0.9990596102606969

# %% [markdown]
# Here we can use random forest features becouse that have high accuracy

# %%
X1 = X[['City','State','Clean Alternative Fuel Vehicle (CAFV) Eligibility_Not eligible due to low battery range',
       'DOL Vehicle ID','Model', 'Legislative District', 'Electric Vehicle Type_Plug-in Hybrid Electric Vehicle (PHEV)']]

# %% [markdown]
# ## Model building & Training and Testing Data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split


# Function to plot Confusion Matrix
def plot_confusion_matrix(y_test, y_pred, model_name):
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"{model_name} - Confusion Matrix")
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# Reduced dataset size for faster testing (e.g., 30% sample of the data)
X_sample, _, y_sample, _ = train_test_split(X1, y, test_size=0.7, random_state=42)

# List of models to implement
models = {
    "Logistic Regression": LogisticRegression(max_iter=100),  # Reduced max_iter for faster convergence
    "SVM": SVC(probability=True, max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=50, n_jobs=-1),  # Reduced n_estimators and use parallel processing
    "Naive Bayes": GaussianNB()
}

# Variables to store the best model details
best_model_name = None
best_model_accuracy = 0

# Train and evaluate each model
for model_name, model in models.items():
    # Train-test split for this model (used sample dataset for faster runs)
    X_train, X_test, y_train, y_test = train_test_split(X_sample, y_sample, test_size=0.3, random_state=42)

    # Train the model
    model.fit(X_train, y_train)
    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    # Evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Confusion Matrix
    print(f"\n{model_name} - Confusion Matrix:")
    plot_confusion_matrix(y_test, y_pred, model_name)

    # Print metrics
    print(f"\n{model_name} Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Update the best model based on accuracy
    if accuracy > best_model_accuracy:
        best_model_accuracy = accuracy
        best_model_name = model_name

# Print the best model's name and its accuracy
print(f"\nThe best model is: {best_model_name} with an accuracy of {best_model_accuracy:.4f}")
# Out:
# Logistic Regression - Confusion Matrix:
# Logistic Regression Metrics:
# Accuracy: 0.7433
# Precision: 0.6189
# Recall: 0.7433
# F1-Score: 0.6420
#
# SVM - Confusion Matrix:
# SVM Metrics:
# Accuracy: 0.4130
# Precision: 0.6293
# Recall: 0.4130
# F1-Score: 0.4608
#
# Decision Tree - Confusion Matrix:
# Decision Tree Metrics:
# Accuracy: 0.8468
# Precision: 0.8470
# Recall: 0.8468
# F1-Score: 0.8469
#
# Random Forest - Confusion Matrix:
# Random Forest Metrics:
# Accuracy: 0.8485
# Precision: 0.8436
# Recall: 0.8485
# F1-Score: 0.8456
#
# Naive Bayes - Confusion Matrix:
# Naive Bayes Metrics:
# Accuracy: 0.1773
# Precision: 0.7485
# Recall: 0.1773
# F1-Score: 0.2097
#
# The best model is: Random Forest with an accuracy of 0.8485

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt

# %%
 # Ensure the model has been trained
y_pred_proba = model.predict_proba(X_test)

# Verify the shape of y_pred_proba
print(f"y_pred_proba shape: {y_pred_proba.shape}")

# Continue with the ROC-AUC analysis
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt

# Binarize y_test for multiclass ROC
classes = np.unique(y_test)
y_test_binarized = label_binarize(y_test, classes=classes)

# Ensure y_test_binarized is properly shaped
if y_test_binarized.ndim == 1:
    y_test_binarized = np.expand_dims(y_test_binarized, axis=1)

# Initialize dictionaries to store FPR, TPR, and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

for i, class_label in enumerate(classes):
    fpr[class_label], tpr[class_label], _ = roc_curve(y_test_binarized[:, i], y_pred_proba[:, i])
    roc_auc[class_label] = roc_auc_score(y_test_binarized[:, i], y_pred_proba[:, i])

# Plot the ROC curves for all classes
for class_label in classes:
    plt.plot(fpr[class_label], tpr[class_label], label=f"Class {class_label} (AUC = {roc_auc[class_label]:.2f})")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Multiclass ROC Curve")
plt.legend()
plt.show()
# Out:
# y_pred_proba shape: (17227, 4)

# %% [markdown]
# ### Handling Class Imbalance in Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE  # Import SMOTE for balancing

# Apply SMOTE to balance the classes in the training data
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# Train a model on the balanced data
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_balanced, y_train_balanced)

# Predict on train and test sets
train_preds = model.predict(X_train_balanced)
test_preds = model.predict(X_test)

# Calculate accuracy
train_acc = accuracy_score(y_train_balanced, train_preds)
test_acc = accuracy_score(y_test, test_preds)

# Print train and test accuracy to compare
print(f"Training Accuracy: {train_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")

# Check for overfitting: Large gap between train and test accuracy means overfitting
if train_acc - test_acc > 0.05:
    print("Overfitting detected!")
else:
    print("No significant overfitting.")
# Out:
# Training Accuracy: 0.9986
# Test Accuracy: 0.8293
# Overfitting detected!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Logistic Regression with L2 regularization
model = LogisticRegression(penalty='l2', solver='saga', max_iter=1000)

# Hyperparameter tuning for regularization strength
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}  # C is the inverse of regularization strength
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best model
best_model = grid_search.best_estimator_
print("Best regularization parameter:", grid_search.best_params_)

# Evaluate performance
train_accuracy = best_model.score(X_train, y_train)
test_accuracy = best_model.score(X_test, y_test)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Best regularization parameter: {'C': 100}
# Training Accuracy: 0.9546
# Test Accuracy: 0.9550

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE  # Import SMOTE for balancing

# Apply SMOTE to balance the classes in the training data
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# Train a model on the balanced data
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_balanced, y_train_balanced)

# Predict on train and test sets
train_preds = model.predict(X_train_balanced)
test_preds = model.predict(X_test)

# Calculate accuracy
train_acc = accuracy_score(y_train_balanced, train_preds)
test_acc = accuracy_score(y_test, test_preds)

# Print train and test accuracy to compare
print(f"Training Accuracy: {train_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")

# Check for overfitting: Large gap between train and test accuracy means overfitting
if train_acc - test_acc > 0.05:
    print("Overfitting detected!")
else:
    print("No significant overfitting.")
# Out:
# Training Accuracy: 1.0000
# Test Accuracy: 0.9987
# No significant overfitting.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV


model = RandomForestClassifier(random_state=42)

# Define the hyperparameters grid
param_dist = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Randomized search for best hyperparameters
random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=50, cv=3, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Best hyperparameters
print(f"Best Parameters: {random_search.best_params_}")

# Evaluate the tuned model
best_model = random_search.best_estimator_
test_preds = best_model.predict(X_test)
test_acc = accuracy_score(y_test, test_preds)
print(f"Test Accuracy with Tuned Model: {test_acc:.4f}")
# Out:
# Best Parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 30, 'bootstrap': True}
# Test Accuracy with Tuned Model: 0.9991

# %% [markdown]
# * **Model Selected :  Random Forest**
# * The refined Random Forest models, particularly Random Forest, exhibited a better balance between training and testing performance, reducing overfitting while maintaining reasonable accuracy.

# %%
import joblib

# %%
pip install joblib

# %%
model_filename = 'Electric_vechile.pkl'
joblib.dump(best_model, model_filename)
# Out:
# ['Electric_vechile.pkl']

# %%
loaded_model = joblib.load(model_filename)

# %%
loaded_model
# Out:
# RandomForestClassifier(max_depth=30, min_samples_split=5, n_estimators=50,
#                        random_state=42)

# %%
df1
# Out:
#              City State  Model Year    Make       Model  \
# 0         Seattle    WA      2019.0   TESLA     MODEL S
# 1          Zillah    WA      2024.0     BMW        330E
# 2            Kent    WA      2015.0  NISSAN        LEAF
# 3         Bothell    WA      2015.0   TESLA     MODEL S
# 4          Yakima    WA      2022.0  TOYOTA  RAV4 PRIME
# ...           ...   ...         ...     ...         ...
# 191402     Sumner    WA      2019.0   TESLA     MODEL 3
# 191403   Wilkeson    WA      2023.0  NISSAN       ARIYA
# 191404  Fall City    WA      2024.0   TESLA     MODEL Y
# 191405   Aberdeen    WA      2022.0   TESLA     MODEL X
# 191406   Richland    WA      2023.0   TESLA     MODEL Y
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1       Plug-in Hybrid Electric Vehicle (PHEV)
# 2               Battery Electric Vehicle (BEV)
# 3               Battery Electric Vehicle (BEV)
# 4       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Define numerical features from your dataset
numerical_features = [ 'Model Year', 'Legislative District']

# Example unseen data with specific values for prediction
unseen_data = pd.DataFrame({
    'Model Year': [3000.0],
    'City': ['Seattle'],
    'State': ['WA'],
    'Make': ['TESLA'],
    'Model': ['MODEL S'],
    'Electric Vehicle Type': ['Battery Electric Vehicle (BEV)'],
    'Legislative District': [50],
    'DOL Vehicle ID': ['202233958']
})


# Encoding Data
unseen_data_encoded = pd.get_dummies(unseen_data, columns=[ 'State', 'Electric Vehicle Type', ], drop_first=True)

for col in ['City', 'DOL Vehicle ID', 'Model', 'Make']:
    freq_encoding = X[col].value_counts(normalize=True)
    unseen_data_encoded[col] = X[col].map(freq_encoding)


# Ensure unseen_data has the same columns as the training data (handled missing columns if needed)
unseen_data_encoded = unseen_data_encoded.reindex(columns=X_train.columns, fill_value=0)

#Scale numerical features
scaler = StandardScaler()
unseen_data_encoded[numerical_features] = scaler.fit_transform(unseen_data_encoded[numerical_features])

# Predict using the pre-trained Random Forest model
predicted_class = loaded_model.predict(unseen_data_encoded)

print("Predicted class:", predicted_class[0])
# Out:
# Predicted class: 1

# %% [markdown]
# ## Conclusion:
# **Model Selected: Random Forest Classifier**
#
# The Random Forest model emerged as the best-performing model, striking an excellent balance between training and test accuracy. It demonstrated robustness and effectively captured the dataset's complex patterns without notable overfitting. Despite challenges like missing data and class imbalance, the model consistently delivered high accuracy across various classes, making it a reliable choice for classification tasks with this dataset. Further improvements could focus on mitigating class imbalance and refining feature engineering to enhance its performance even further.

# %% [markdown]
# ## Future Work:
#
# * **Address Class Imbalance:** Apply techniques like SMOTE or class weighting to better handle class imbalance, enhancing predictions for underrepresented classes.
#
# * **Incorporate Temporal Features:** Utilize time-series models or derive temporal features such as lagged variables and rolling statistics to capture seasonal trends and patterns more effectively.
#
# * **Enhance Feature Engineering:** Create additional features, such as seasonal indicators or interactions between variables, to improve the model's predictive capability.
#
# * **Leverage Advanced Ensemble Methods:** Experiment with methods like stacking, boosting (e.g., XGBoost, LightGBM), or hybrid approaches to further enhance model performance.
#
# * **Retrain with Updated Data:** Regularly update the model with new data to adapt to emerging trends and maintain optimal performance over time.
#
# * **Improve Model Explainability:** Employ tools like SHAP or LIME to provide deeper insights into model decisions, fostering transparency and trust among stakeholders.
